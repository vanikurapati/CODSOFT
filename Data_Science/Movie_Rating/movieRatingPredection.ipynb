# %%
import pandas as pd, numpy as np
import matplotlib.pyplot as plt, seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
df = pd.read_csv("Movies.csv", encoding='ISO-8859-1')

# %%
df.info(), df.describe(), df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15509 entries, 0 to 15508
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      15509 non-null  object
#  1   Year      14981 non-null  float64
#  2   Duration  7240 non-null   object
#  3   Genre     13632 non-null  object
#  4   Rating    7919 non-null   float64
#  5   Votes     7920 non-null   object
#  6   Director  14984 non-null  object
#  7   Actor 1   13892 non-null  object
#  8   Actor 2   13125 non-null  object
#  9   Actor 3   12365 non-null  object
# dtypes: float64(2), object(8)
# memory usage: 1.2+ MB
# (None,
#                 Year       Rating
#  count  14981.000000  7919.000000
#  mean   -1987.012215     5.841621
#  std       25.416689     1.381777
#  min    -2022.000000     1.100000
#  25%    -2009.000000     4.900000
#  50%    -1991.000000     6.000000
#  75%    -1968.000000     6.800000
#  max    -1913.000000    10.000000,
# ...

# %%
df.dropna(inplace=True)
df = df[df['Rating'].notnull()]

# %%
selected_features = df[['Genre', 'Director', 'Actor 1', 'Actor 2', 'Actor 3', 'Year', 'Duration']]
target = df['Rating']

# %%
for col in ['Genre', 'Director', 'Actor 1', 'Actor 2', 'Actor 3']:
    le = LabelEncoder()
    selected_features[col] = le.fit_transform(selected_features[col])
# Out:
# C:\Users\Rakesh\AppData\Local\Temp\ipykernel_3408\2437030963.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_features[col] = le.fit_transform(selected_features[col])
# C:\Users\Rakesh\AppData\Local\Temp\ipykernel_3408\2437030963.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_features[col] = le.fit_transform(selected_features[col])
# C:\Users\Rakesh\AppData\Local\Temp\ipykernel_3408\2437030963.py:3: SettingWithCopyWarning:
# ...

# %%
def convert_duration(duration):
    ...
df['Duration'] = df['Duration'].apply(convert_duration)

# %%
df['Votes'] = df['Votes'].astype(str).str.replace(',', '', regex=True)
df['Votes'] = pd.to_numeric(df['Votes'], errors='coerce')

# %%
selected_features = df[['Genre', 'Director', 'Actor 1', 'Actor 2', 'Actor 3', 'Year', 'Duration', 'Votes']]
target = df['Rating']

# %%
X_train, X_test, y_train, y_test = train_test_split(selected_features, target, test_size=0.2, random_state=42)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3408\1905445833.py in ?()
# ----> 2 model = LinearRegression()
#       3 model.fit(X_train, y_train)
#
# c:\Users\Rakesh\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1385                 skip_parameter_validation=(
#    1386                     prefer_skip_nested_validation or global_skip_validation
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#
# c:\Users\Rakesh\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\linear_model\_base.py in ?(self, X, y, sample_weight)
#     597         n_jobs_ = self.n_jobs
#     598
#     599         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     600
# ...

# %%
import pandas as pd

# If X_train is a DataFrame
X_train_encoded = pd.get_dummies(X_train)

# Then fit the model
model = LinearRegression()
model.fit(X_train_encoded, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
X_train['genre'] = le.fit_transform(X_train['genre'])  # Replace 'genre' with your column name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 from sklearn.preprocessing import LabelEncoder
#       3 le = LabelEncoder()
# ----> 4 X_train['genre'] = le.fit_transform(X_train['genre'])  # Replace 'genre' with your column name
#
# NameError: name 'X_train' is not defined
